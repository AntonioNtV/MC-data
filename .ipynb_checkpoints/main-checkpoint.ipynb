# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from data_transform_utils import rename_columns, parse_columns

# %% [markdown]
# # Data Treating

# %%
raw_data = pd.read_csv('./assets/survey_data.csv')

# %%
parsed_data = raw_data.pipe(rename_columns).pipe(parse_columns)

# %%
parsed_data.sample(10)
# Out:
#     reference_date age_group college_term  diagnosed_with_ler  \
# 56      2022-07-12     18-21            5                   0
# 106     2022-08-01     22-25            6                   0
# 102     2022-08-01     22-25            8                   0
# 30      2022-07-04     18-21            7                   0
# 61      2022-07-12     22-25            7                   0
# 44      2022-07-07     22-25            2                   0
# 92      2022-07-15     18-21            8                   0
# 72      2022-07-12     22-25            2                   0
# 101     2022-08-01     22-25            6                   0
# 75      2022-07-12     18-21            2                   0
#
#      practice_exercises  practice_stretching  has_ergonomic_chair  \
# 56                    1                    1                    4
# 106                   1                    1                    2
# 102                   2                    1                    4
# 30                    2                    2                    2
# 61                    5                    3                    2
# 44                    3                    2                    1
# 92                    2                    1                    2
# 72                    3                    4                    1
# 101                   1                    1                    1
# 75                    4                    1                    1
#
#      has_wrist_support  has_tendinitis  has_muscle_aches  ...  has_backache  \
# 56                   1               0                 0  ...             1
# 106                  1               0                 1  ...             1
# 102                  1               0                 0  ...             0
# 30                   3               0                 0  ...             0
# 61                   1               0                 0  ...             0
# 44                   2               0                 0  ...             0
# 92                   1               0                 0  ...             0
# 72                   1               1                 0  ...             1
# 101                  1               0                 0  ...             0
# 75                   1               0                 0  ...             1
#
#      has_bursitis  has_dry_eye_syndrome  has_eyestrain  already_graduated  \
# 56              1                     0              1                  0
# 106             0                     0              0                  0
# 102             0                     0              0                  0
# 30              0                     0              0                  0
# 61              0                     0              0                  0
# 44              0                     0              0                  0
# 92              0                     0              1                  0
# 72              0                     0              1                  0
# 101             0                     0              1                  0
# 75              0                     0              1                  0
#
#      less_then_1hour  between_1_and_3_hours  between_3_and_5_hours  \
# 56                 0                      0                      0
# 106                0                      0                      0
# 102                0                      0                      0
# 30                 0                      0                      0
# 61                 0                      1                      0
# 44                 0                      0                      1
# 92                 0                      0                      0
# 72                 0                      0                      0
# 101                0                      0                      0
# 75                 0                      0                      0
#
#      between_5_and_8_hours  more_then_8_hours
# 56                       0                  1
# 106                      0                  1
# 102                      1                  0
# 30                       1                  0
# 61                       0                  0
# 44                       0                  0
# 92                       0                  1
# 72                       1                  0
# 101                      0                  1
# 75                       1                  0
#
# [10 rows x 21 columns]

# %% [markdown]
# # Data Analysis

# %%
data_corr = parsed_data.corr(method='pearson')
mask = np.zeros_like(data_corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(16, 14))
sns.heatmap(data_corr, mask=mask, annot=True, fmt='.2f', cmap=plt.cm.Blues)
plt.show()
